# %%
from kafka import KafkaProducer
import pandas as pd
import time
import random

# Membaca file CSV
df = pd.read_csv('2020-Jan.csv')

# Inisialisasi Kafka Producer
producer = KafkaProducer(bootstrap_servers='localhost:9092')

# Print info tentang inisialisasi
print("Kafka Producer initialized and connected to localhost:9092.")

# Kirim data ke Kafka
for index, row in df.iterrows():
    # Konversi row menjadi JSON dan encode sebagai bytes
    message = row.to_json().encode('utf-8')

    # Debug: Tampilkan beberapa informasi tentang baris yang sedang diproses
    print(f"Sending message {index + 1} to Kafka topic 'quiz-2'. Data: {message[:100]}...")  # Print sebagian data untuk menghindari terlalu panjang

    # Mengirimkan pesan ke topik 'quiz-2'
    producer.send('quiz-2', message)

    # Debug: Berikan informasi bahwa pesan telah dikirim
    print(f"Message {index + 1} sent to Kafka.")

    # Sleep random untuk simulasi streaming
    sleep_time = random.uniform(0.5, 2)
    print(f"Sleeping for {sleep_time:.2f} seconds before sending next message.\n")
    time.sleep(sleep_time)

# Menutup koneksi producer setelah pengiriman selesai
producer.close()
print("Kafka Producer closed.")

# %%
from kafka import KafkaConsumer
import json
import pandas as pd
import os

# Inisialisasi Kafka Consumer
consumer = KafkaConsumer('quiz-2', group_id='your_group', bootstrap_servers='localhost:9092')

# Variabel untuk menyimpan batch data
batch_size = 1000
batch_data = []

# Nama file untuk menyimpan batch ke CSV
csv_file = 'batch_data.csv'

# Fungsi untuk menyimpan batch ke file CSV
def save_batch_to_csv(batch_data, file_name):
    # Mengonversi batch data menjadi DataFrame
    df = pd.DataFrame(batch_data)

    # Mengecek apakah file CSV sudah ada atau belum
    if os.path.exists(file_name):
        # Jika sudah ada, tambahkan data ke file yang sudah ada
        df.to_csv(file_name, mode='a', header=False, index=False)
    else:
        # Jika belum ada, buat file baru dan simpan dengan header
        df.to_csv(file_name, mode='w', header=True, index=False)

# Loop untuk mengonsumsi data dari Kafka
for message in consumer:
    # Menambahkan data pesan yang diterima ke dalam batch
    batch_data.append(json.loads(message.value))

    # Debug: Print ukuran batch yang telah terisi
    print(f"Batch size: {len(batch_data)} (Waiting for {batch_size - len(batch_data)} more records to reach {batch_size}).")

    # Jika sudah mencapai ukuran batch yang diinginkan
    if len(batch_data) >= batch_size:
        # Proses batch data
        print(f"Processing batch of {batch_size} records...")

        # Debug: Tampilkan contoh data yang akan diproses
        print(f"Example data from the batch: {batch_data[0]}")

        # Simpan batch data ke CSV
        save_batch_to_csv(batch_data, csv_file)

        # Kosongkan batch_data setelah disimpan
        batch_data = []
# Out:
# Batch size: 1 (Waiting for 999 more records to reach 1000).
# Batch size: 2 (Waiting for 998 more records to reach 1000).
# Batch size: 3 (Waiting for 997 more records to reach 1000).
# Batch size: 4 (Waiting for 996 more records to reach 1000).
# Batch size: 5 (Waiting for 995 more records to reach 1000).
# Batch size: 6 (Waiting for 994 more records to reach 1000).
# Batch size: 7 (Waiting for 993 more records to reach 1000).
# Batch size: 8 (Waiting for 992 more records to reach 1000).
# Batch size: 9 (Waiting for 991 more records to reach 1000).
# Batch size: 10 (Waiting for 990 more records to reach 1000).
# Batch size: 11 (Waiting for 989 more records to reach 1000).
# Batch size: 12 (Waiting for 988 more records to reach 1000).
# Batch size: 13 (Waiting for 987 more records to reach 1000).
# Batch size: 14 (Waiting for 986 more records to reach 1000).
# Batch size: 15 (Waiting for 985 more records to reach 1000).
# Batch size: 16 (Waiting for 984 more records to reach 1000).
# Batch size: 17 (Waiting for 983 more records to reach 1000).
# Batch size: 18 (Waiting for 982 more records to reach 1000).
# Batch size: 19 (Waiting for 981 more records to reach 1000).
# Batch size: 20 (Waiting for 980 more records to reach 1000).
# Batch size: 21 (Waiting for 979 more records to reach 1000).
# Batch size: 22 (Waiting for 978 more records to reach 1000).
# Batch size: 23 (Waiting for 977 more records to reach 1000).
# Batch size: 24 (Waiting for 976 more records to reach 1000).
# Batch size: 25 (Waiting for 975 more records to reach 1000).
# Batch size: 26 (Waiting for 974 more records to reach 1000).
# Batch size: 27 (Waiting for 973 more records to reach 1000).
# Batch size: 28 (Waiting for 972 more records to reach 1000).
# Batch size: 29 (Waiting for 971 more records to reach 1000).
# Batch size: 30 (Waiting for 970 more records to reach 1000).
# Batch size: 31 (Waiting for 969 more records to reach 1000).
# Batch size: 32 (Waiting for 968 more records to reach 1000).
# Batch size: 33 (Waiting for 967 more records to reach 1000).
# Batch size: 34 (Waiting for 966 more records to reach 1000).
# Batch size: 35 (Waiting for 965 more records to reach 1000).
# Batch size: 36 (Waiting for 964 more records to reach 1000).
# Batch size: 37 (Waiting for 963 more records to reach 1000).
# Batch size: 38 (Waiting for 962 more records to reach 1000).
# Batch size: 39 (Waiting for 961 more records to reach 1000).
# Batch size: 40 (Waiting for 960 more records to reach 1000).
# Batch size: 41 (Waiting for 959 more records to reach 1000).
# Batch size: 42 (Waiting for 958 more records to reach 1000).
# Batch size: 43 (Waiting for 957 more records to reach 1000).
# Batch size: 44 (Waiting for 956 more records to reach 1000).
# Batch size: 45 (Waiting for 955 more records to reach 1000).
# Batch size: 46 (Waiting for 954 more records to reach 1000).
# Batch size: 47 (Waiting for 953 more records to reach 1000).
# Batch size: 48 (Waiting for 952 more records to reach 1000).
# Batch size: 49 (Waiting for 951 more records to reach 1000).
# Batch size: 50 (Waiting for 950 more records to reach 1000).
# Batch size: 51 (Waiting for 949 more records to reach 1000).
# Batch size: 52 (Waiting for 948 more records to reach 1000).
# Batch size: 53 (Waiting for 947 more records to reach 1000).
# Batch size: 54 (Waiting for 946 more records to reach 1000).
# Batch size: 55 (Waiting for 945 more records to reach 1000).
# Batch size: 56 (Waiting for 944 more records to reach 1000).
# Batch size: 57 (Waiting for 943 more records to reach 1000).
# Batch size: 58 (Waiting for 942 more records to reach 1000).
# Batch size: 59 (Waiting for 941 more records to reach 1000).
# Batch size: 60 (Waiting for 940 more records to reach 1000).
# Batch size: 61 (Waiting for 939 more records to reach 1000).
# Batch size: 62 (Waiting for 938 more records to reach 1000).
# Batch size: 63 (Waiting for 937 more records to reach 1000).
# Batch size: 64 (Waiting for 936 more records to reach 1000).
# Batch size: 65 (Waiting for 935 more records to reach 1000).
# Batch size: 66 (Waiting for 934 more records to reach 1000).
# Batch size: 67 (Waiting for 933 more records to reach 1000).
# Batch size: 68 (Waiting for 932 more records to reach 1000).
# Batch size: 69 (Waiting for 931 more records to reach 1000).
# Batch size: 70 (Waiting for 930 more records to reach 1000).
# Batch size: 71 (Waiting for 929 more records to reach 1000).
# Batch size: 72 (Waiting for 928 more records to reach 1000).
# Batch size: 73 (Waiting for 927 more records to reach 1000).
# Batch size: 74 (Waiting for 926 more records to reach 1000).
# Batch size: 75 (Waiting for 925 more records to reach 1000).
# Batch size: 76 (Waiting for 924 more records to reach 1000).
# Batch size: 77 (Waiting for 923 more records to reach 1000).
# Batch size: 78 (Waiting for 922 more records to reach 1000).
# Batch size: 79 (Waiting for 921 more records to reach 1000).
# Batch size: 80 (Waiting for 920 more records to reach 1000).
# Batch size: 81 (Waiting for 919 more records to reach 1000).
# Batch size: 82 (Waiting for 918 more records to reach 1000).
# Batch size: 83 (Waiting for 917 more records to reach 1000).
# Batch size: 84 (Waiting for 916 more records to reach 1000).
# Batch size: 85 (Waiting for 915 more records to reach 1000).
# Batch size: 86 (Waiting for 914 more records to reach 1000).
# Batch size: 87 (Waiting for 913 more records to reach 1000).
# Batch size: 88 (Waiting for 912 more records to reach 1000).
# Batch size: 89 (Waiting for 911 more records to reach 1000).
# Batch size: 90 (Waiting for 910 more records to reach 1000).
# Batch size: 91 (Waiting for 909 more records to reach 1000).
# Batch size: 92 (Waiting for 908 more records to reach 1000).
# Batch size: 93 (Waiting for 907 more records to reach 1000).
# Batch size: 94 (Waiting for 906 more records to reach 1000).
# Batch size: 95 (Waiting for 905 more records to reach 1000).
# Batch size: 96 (Waiting for 904 more records to reach 1000).
# Batch size: 97 (Waiting for 903 more records to reach 1000).
# Batch size: 98 (Waiting for 902 more records to reach 1000).
# Batch size: 99 (Waiting for 901 more records to reach 1000).
# Batch size: 100 (Waiting for 900 more records to reach 1000).
# Batch size: 101 (Waiting for 899 more records to reach 1000).
# Batch size: 102 (Waiting for 898 more records to reach 1000).
# Batch size: 103 (Waiting for 897 more records to reach 1000).
# Batch size: 104 (Waiting for 896 more records to reach 1000).
# Batch size: 105 (Waiting for 895 more records to reach 1000).
# Batch size: 106 (Waiting for 894 more records to reach 1000).
# Batch size: 107 (Waiting for 893 more records to reach 1000).
# Batch size: 108 (Waiting for 892 more records to reach 1000).
# Batch size: 109 (Waiting for 891 more records to reach 1000).
# Batch size: 110 (Waiting for 890 more records to reach 1000).
# Batch size: 111 (Waiting for 889 more records to reach 1000).
# Batch size: 112 (Waiting for 888 more records to reach 1000).
# Batch size: 113 (Waiting for 887 more records to reach 1000).
# Batch size: 114 (Waiting for 886 more records to reach 1000).
# Batch size: 115 (Waiting for 885 more records to reach 1000).
# Batch size: 116 (Waiting for 884 more records to reach 1000).
# Batch size: 117 (Waiting for 883 more records to reach 1000).
# Batch size: 118 (Waiting for 882 more records to reach 1000).
# Batch size: 119 (Waiting for 881 more records to reach 1000).
# Batch size: 120 (Waiting for 880 more records to reach 1000).
# Batch size: 121 (Waiting for 879 more records to reach 1000).
# Batch size: 122 (Waiting for 878 more records to reach 1000).
# Batch size: 123 (Waiting for 877 more records to reach 1000).
# Batch size: 124 (Waiting for 876 more records to reach 1000).
# Batch size: 125 (Waiting for 875 more records to reach 1000).
# Batch size: 126 (Waiting for 874 more records to reach 1000).
# Batch size: 127 (Waiting for 873 more records to reach 1000).
# Batch size: 128 (Waiting for 872 more records to reach 1000).
# Batch size: 129 (Waiting for 871 more records to reach 1000).
# Batch size: 130 (Waiting for 870 more records to reach 1000).
# Batch size: 131 (Waiting for 869 more records to reach 1000).
# Batch size: 132 (Waiting for 868 more records to reach 1000).
# Batch size: 133 (Waiting for 867 more records to reach 1000).
# Batch size: 134 (Waiting for 866 more records to reach 1000).
# Batch size: 135 (Waiting for 865 more records to reach 1000).
# Batch size: 136 (Waiting for 864 more records to reach 1000).
# Batch size: 137 (Waiting for 863 more records to reach 1000).
# Batch size: 138 (Waiting for 862 more records to reach 1000).
# Batch size: 139 (Waiting for 861 more records to reach 1000).
# Batch size: 140 (Waiting for 860 more records to reach 1000).
# Batch size: 141 (Waiting for 859 more records to reach 1000).
# Batch size: 142 (Waiting for 858 more records to reach 1000).
# Batch size: 143 (Waiting for 857 more records to reach 1000).
# Batch size: 144 (Waiting for 856 more records to reach 1000).
# Batch size: 145 (Waiting for 855 more records to reach 1000).
# Batch size: 146 (Waiting for 854 more records to reach 1000).
# Batch size: 147 (Waiting for 853 more records to reach 1000).
# Batch size: 148 (Waiting for 852 more records to reach 1000).
# Batch size: 149 (Waiting for 851 more records to reach 1000).
# Batch size: 150 (Waiting for 850 more records to reach 1000).
# Batch size: 151 (Waiting for 849 more records to reach 1000).
# Batch size: 152 (Waiting for 848 more records to reach 1000).
# Batch size: 153 (Waiting for 847 more records to reach 1000).
# Batch size: 154 (Waiting for 846 more records to reach 1000).
# Batch size: 155 (Waiting for 845 more records to reach 1000).
# Batch size: 156 (Waiting for 844 more records to reach 1000).
# Batch size: 157 (Waiting for 843 more records to reach 1000).
# Batch size: 158 (Waiting for 842 more records to reach 1000).
# Batch size: 159 (Waiting for 841 more records to reach 1000).
# Batch size: 160 (Waiting for 840 more records to reach 1000).
# Batch size: 161 (Waiting for 839 more records to reach 1000).
# Batch size: 162 (Waiting for 838 more records to reach 1000).
# Batch size: 163 (Waiting for 837 more records to reach 1000).
# Batch size: 164 (Waiting for 836 more records to reach 1000).
# Batch size: 165 (Waiting for 835 more records to reach 1000).
# Batch size: 166 (Waiting for 834 more records to reach 1000).
# Batch size: 167 (Waiting for 833 more records to reach 1000).
# Batch size: 168 (Waiting for 832 more records to reach 1000).
# Batch size: 169 (Waiting for 831 more records to reach 1000).
# Batch size: 170 (Waiting for 830 more records to reach 1000).
# Batch size: 171 (Waiting for 829 more records to reach 1000).
# Batch size: 172 (Waiting for 828 more records to reach 1000).
# Batch size: 173 (Waiting for 827 more records to reach 1000).
# Batch size: 174 (Waiting for 826 more records to reach 1000).
# Batch size: 175 (Waiting for 825 more records to reach 1000).
# Batch size: 176 (Waiting for 824 more records to reach 1000).
# Batch size: 177 (Waiting for 823 more records to reach 1000).
# Batch size: 178 (Waiting for 822 more records to reach 1000).
# Batch size: 179 (Waiting for 821 more records to reach 1000).
# Batch size: 180 (Waiting for 820 more records to reach 1000).
# Batch size: 181 (Waiting for 819 more records to reach 1000).
# Batch size: 182 (Waiting for 818 more records to reach 1000).
# Batch size: 183 (Waiting for 817 more records to reach 1000).
# Batch size: 184 (Waiting for 816 more records to reach 1000).
# Batch size: 185 (Waiting for 815 more records to reach 1000).
# Batch size: 186 (Waiting for 814 more records to reach 1000).
# Batch size: 187 (Waiting for 813 more records to reach 1000).
# Batch size: 188 (Waiting for 812 more records to reach 1000).
# Batch size: 189 (Waiting for 811 more records to reach 1000).
# Batch size: 190 (Waiting for 810 more records to reach 1000).
# Batch size: 191 (Waiting for 809 more records to reach 1000).
# Batch size: 192 (Waiting for 808 more records to reach 1000).
# Batch size: 193 (Waiting for 807 more records to reach 1000).
# Batch size: 194 (Waiting for 806 more records to reach 1000).
# Batch size: 195 (Waiting for 805 more records to reach 1000).
# Batch size: 196 (Waiting for 804 more records to reach 1000).
# Batch size: 197 (Waiting for 803 more records to reach 1000).
# Batch size: 198 (Waiting for 802 more records to reach 1000).
# Batch size: 199 (Waiting for 801 more records to reach 1000).
# Batch size: 200 (Waiting for 800 more records to reach 1000).
# Batch size: 201 (Waiting for 799 more records to reach 1000).
# Batch size: 202 (Waiting for 798 more records to reach 1000).
# Batch size: 203 (Waiting for 797 more records to reach 1000).
# Batch size: 204 (Waiting for 796 more records to reach 1000).
# Batch size: 205 (Waiting for 795 more records to reach 1000).
# Batch size: 206 (Waiting for 794 more records to reach 1000).
# Batch size: 207 (Waiting for 793 more records to reach 1000).
# Batch size: 208 (Waiting for 792 more records to reach 1000).
# Batch size: 209 (Waiting for 791 more records to reach 1000).
# Batch size: 210 (Waiting for 790 more records to reach 1000).
# Batch size: 211 (Waiting for 789 more records to reach 1000).
# Batch size: 212 (Waiting for 788 more records to reach 1000).
# Batch size: 213 (Waiting for 787 more records to reach 1000).
# Batch size: 214 (Waiting for 786 more records to reach 1000).
# Batch size: 215 (Waiting for 785 more records to reach 1000).
# Batch size: 216 (Waiting for 784 more records to reach 1000).
# Batch size: 217 (Waiting for 783 more records to reach 1000).
# Batch size: 218 (Waiting for 782 more records to reach 1000).
# Batch size: 219 (Waiting for 781 more records to reach 1000).
# Batch size: 220 (Waiting for 780 more records to reach 1000).
# Batch size: 221 (Waiting for 779 more records to reach 1000).
# Batch size: 222 (Waiting for 778 more records to reach 1000).
# Batch size: 223 (Waiting for 777 more records to reach 1000).
# Batch size: 224 (Waiting for 776 more records to reach 1000).
# Batch size: 225 (Waiting for 775 more records to reach 1000).
# Batch size: 226 (Waiting for 774 more records to reach 1000).
# Batch size: 227 (Waiting for 773 more records to reach 1000).
# Batch size: 228 (Waiting for 772 more records to reach 1000).
# Batch size: 229 (Waiting for 771 more records to reach 1000).
# Batch size: 230 (Waiting for 770 more records to reach 1000).
# Batch size: 231 (Waiting for 769 more records to reach 1000).
# Batch size: 232 (Waiting for 768 more records to reach 1000).
# Batch size: 233 (Waiting for 767 more records to reach 1000).
# Batch size: 234 (Waiting for 766 more records to reach 1000).
# Batch size: 235 (Waiting for 765 more records to reach 1000).
# Batch size: 236 (Waiting for 764 more records to reach 1000).
# Batch size: 237 (Waiting for 763 more records to reach 1000).
# Batch size: 238 (Waiting for 762 more records to reach 1000).
# Batch size: 239 (Waiting for 761 more records to reach 1000).
# Batch size: 240 (Waiting for 760 more records to reach 1000).
# Batch size: 241 (Waiting for 759 more records to reach 1000).
# Batch size: 242 (Waiting for 758 more records to reach 1000).
# Batch size: 243 (Waiting for 757 more records to reach 1000).
# Batch size: 244 (Waiting for 756 more records to reach 1000).
# Batch size: 245 (Waiting for 755 more records to reach 1000).
# Batch size: 246 (Waiting for 754 more records to reach 1000).
# Batch size: 247 (Waiting for 753 more records to reach 1000).
# Batch size: 248 (Waiting for 752 more records to reach 1000).
# Batch size: 249 (Waiting for 751 more records to reach 1000).
# Batch size: 250 (Waiting for 750 more records to reach 1000).
# Batch size: 251 (Waiting for 749 more records to reach 1000).
# Batch size: 252 (Waiting for 748 more records to reach 1000).
# Batch size: 253 (Waiting for 747 more records to reach 1000).
# Batch size: 254 (Waiting for 746 more records to reach 1000).
# Batch size: 255 (Waiting for 745 more records to reach 1000).
# Batch size: 256 (Waiting for 744 more records to reach 1000).
# Batch size: 257 (Waiting for 743 more records to reach 1000).
# Batch size: 258 (Waiting for 742 more records to reach 1000).
# Batch size: 259 (Waiting for 741 more records to reach 1000).
# Batch size: 260 (Waiting for 740 more records to reach 1000).
# Batch size: 261 (Waiting for 739 more records to reach 1000).
# Batch size: 262 (Waiting for 738 more records to reach 1000).
# Batch size: 263 (Waiting for 737 more records to reach 1000).
# Batch size: 264 (Waiting for 736 more records to reach 1000).
# Batch size: 265 (Waiting for 735 more records to reach 1000).
# Batch size: 266 (Waiting for 734 more records to reach 1000).
# Batch size: 267 (Waiting for 733 more records to reach 1000).
# Batch size: 268 (Waiting for 732 more records to reach 1000).
# Batch size: 269 (Waiting for 731 more records to reach 1000).
# Batch size: 270 (Waiting for 730 more records to reach 1000).
# Batch size: 271 (Waiting for 729 more records to reach 1000).
# Batch size: 272 (Waiting for 728 more records to reach 1000).
# Batch size: 273 (Waiting for 727 more records to reach 1000).
# Batch size: 274 (Waiting for 726 more records to reach 1000).
# Batch size: 275 (Waiting for 725 more records to reach 1000).
# Batch size: 276 (Waiting for 724 more records to reach 1000).
# Batch size: 277 (Waiting for 723 more records to reach 1000).
# Batch size: 278 (Waiting for 722 more records to reach 1000).
# Batch size: 279 (Waiting for 721 more records to reach 1000).
# Batch size: 280 (Waiting for 720 more records to reach 1000).
# Batch size: 281 (Waiting for 719 more records to reach 1000).
# Batch size: 282 (Waiting for 718 more records to reach 1000).
# Batch size: 283 (Waiting for 717 more records to reach 1000).
# Batch size: 284 (Waiting for 716 more records to reach 1000).
# Batch size: 285 (Waiting for 715 more records to reach 1000).
# Batch size: 286 (Waiting for 714 more records to reach 1000).
# Batch size: 287 (Waiting for 713 more records to reach 1000).
# Batch size: 288 (Waiting for 712 more records to reach 1000).
# Batch size: 289 (Waiting for 711 more records to reach 1000).
# Batch size: 290 (Waiting for 710 more records to reach 1000).
# Batch size: 291 (Waiting for 709 more records to reach 1000).
# Batch size: 292 (Waiting for 708 more records to reach 1000).
# Batch size: 293 (Waiting for 707 more records to reach 1000).
# Batch size: 294 (Waiting for 706 more records to reach 1000).
# Batch size: 295 (Waiting for 705 more records to reach 1000).
# Batch size: 296 (Waiting for 704 more records to reach 1000).
# Batch size: 297 (Waiting for 703 more records to reach 1000).
# Batch size: 298 (Waiting for 702 more records to reach 1000).
# Batch size: 299 (Waiting for 701 more records to reach 1000).
# Batch size: 300 (Waiting for 700 more records to reach 1000).
# Batch size: 301 (Waiting for 699 more records to reach 1000).
# Batch size: 302 (Waiting for 698 more records to reach 1000).
# Batch size: 303 (Waiting for 697 more records to reach 1000).
# Batch size: 304 (Waiting for 696 more records to reach 1000).
# Batch size: 305 (Waiting for 695 more records to reach 1000).
# Batch size: 306 (Waiting for 694 more records to reach 1000).
# Batch size: 307 (Waiting for 693 more records to reach 1000).
# Batch size: 308 (Waiting for 692 more records to reach 1000).
# Batch size: 309 (Waiting for 691 more records to reach 1000).
# Batch size: 310 (Waiting for 690 more records to reach 1000).
# Batch size: 311 (Waiting for 689 more records to reach 1000).
# Batch size: 312 (Waiting for 688 more records to reach 1000).
# Batch size: 313 (Waiting for 687 more records to reach 1000).
# Batch size: 314 (Waiting for 686 more records to reach 1000).
# Batch size: 315 (Waiting for 685 more records to reach 1000).
# Batch size: 316 (Waiting for 684 more records to reach 1000).
# Batch size: 317 (Waiting for 683 more records to reach 1000).
# Batch size: 318 (Waiting for 682 more records to reach 1000).
# Batch size: 319 (Waiting for 681 more records to reach 1000).
# Batch size: 320 (Waiting for 680 more records to reach 1000).
# Batch size: 321 (Waiting for 679 more records to reach 1000).
# Batch size: 322 (Waiting for 678 more records to reach 1000).
# Batch size: 323 (Waiting for 677 more records to reach 1000).
# Batch size: 324 (Waiting for 676 more records to reach 1000).
# Batch size: 325 (Waiting for 675 more records to reach 1000).
# Batch size: 326 (Waiting for 674 more records to reach 1000).
# Batch size: 327 (Waiting for 673 more records to reach 1000).
# Batch size: 328 (Waiting for 672 more records to reach 1000).
# Batch size: 329 (Waiting for 671 more records to reach 1000).
# Batch size: 330 (Waiting for 670 more records to reach 1000).
# Batch size: 331 (Waiting for 669 more records to reach 1000).
# Batch size: 332 (Waiting for 668 more records to reach 1000).
# Batch size: 333 (Waiting for 667 more records to reach 1000).
# Batch size: 334 (Waiting for 666 more records to reach 1000).
# Batch size: 335 (Waiting for 665 more records to reach 1000).
# Batch size: 336 (Waiting for 664 more records to reach 1000).
# Batch size: 337 (Waiting for 663 more records to reach 1000).
# Batch size: 338 (Waiting for 662 more records to reach 1000).
# Batch size: 339 (Waiting for 661 more records to reach 1000).
# Batch size: 340 (Waiting for 660 more records to reach 1000).
# Batch size: 341 (Waiting for 659 more records to reach 1000).
# Batch size: 342 (Waiting for 658 more records to reach 1000).
# Batch size: 343 (Waiting for 657 more records to reach 1000).
# Batch size: 344 (Waiting for 656 more records to reach 1000).
# Batch size: 345 (Waiting for 655 more records to reach 1000).
# Batch size: 346 (Waiting for 654 more records to reach 1000).
# Batch size: 347 (Waiting for 653 more records to reach 1000).
# Batch size: 348 (Waiting for 652 more records to reach 1000).
# Batch size: 349 (Waiting for 651 more records to reach 1000).
# Batch size: 350 (Waiting for 650 more records to reach 1000).
# Batch size: 351 (Waiting for 649 more records to reach 1000).
# Batch size: 352 (Waiting for 648 more records to reach 1000).
# Batch size: 353 (Waiting for 647 more records to reach 1000).
# Batch size: 354 (Waiting for 646 more records to reach 1000).
# Batch size: 355 (Waiting for 645 more records to reach 1000).
# Batch size: 356 (Waiting for 644 more records to reach 1000).
# Batch size: 357 (Waiting for 643 more records to reach 1000).
# Batch size: 358 (Waiting for 642 more records to reach 1000).
# Batch size: 359 (Waiting for 641 more records to reach 1000).
# Batch size: 360 (Waiting for 640 more records to reach 1000).
# Batch size: 361 (Waiting for 639 more records to reach 1000).
# Batch size: 362 (Waiting for 638 more records to reach 1000).
# Batch size: 363 (Waiting for 637 more records to reach 1000).
# Batch size: 364 (Waiting for 636 more records to reach 1000).
# Batch size: 365 (Waiting for 635 more records to reach 1000).
# Batch size: 366 (Waiting for 634 more records to reach 1000).
# Batch size: 367 (Waiting for 633 more records to reach 1000).
# Batch size: 368 (Waiting for 632 more records to reach 1000).
# Batch size: 369 (Waiting for 631 more records to reach 1000).
# Batch size: 370 (Waiting for 630 more records to reach 1000).
# Batch size: 371 (Waiting for 629 more records to reach 1000).
# Batch size: 372 (Waiting for 628 more records to reach 1000).
# Batch size: 373 (Waiting for 627 more records to reach 1000).
# Batch size: 374 (Waiting for 626 more records to reach 1000).
# Batch size: 375 (Waiting for 625 more records to reach 1000).
# Batch size: 376 (Waiting for 624 more records to reach 1000).
# Batch size: 377 (Waiting for 623 more records to reach 1000).
# Batch size: 378 (Waiting for 622 more records to reach 1000).
# Batch size: 379 (Waiting for 621 more records to reach 1000).
# Batch size: 380 (Waiting for 620 more records to reach 1000).
# Batch size: 381 (Waiting for 619 more records to reach 1000).
# Batch size: 382 (Waiting for 618 more records to reach 1000).
# Batch size: 383 (Waiting for 617 more records to reach 1000).
# Batch size: 384 (Waiting for 616 more records to reach 1000).
# Batch size: 385 (Waiting for 615 more records to reach 1000).
# Batch size: 386 (Waiting for 614 more records to reach 1000).
# Batch size: 387 (Waiting for 613 more records to reach 1000).
# Batch size: 388 (Waiting for 612 more records to reach 1000).
# Batch size: 389 (Waiting for 611 more records to reach 1000).
# Batch size: 390 (Waiting for 610 more records to reach 1000).
# Batch size: 391 (Waiting for 609 more records to reach 1000).
# Batch size: 392 (Waiting for 608 more records to reach 1000).
# Batch size: 393 (Waiting for 607 more records to reach 1000).
# Batch size: 394 (Waiting for 606 more records to reach 1000).
# Batch size: 395 (Waiting for 605 more records to reach 1000).
# Batch size: 396 (Waiting for 604 more records to reach 1000).
# Batch size: 397 (Waiting for 603 more records to reach 1000).
# Batch size: 398 (Waiting for 602 more records to reach 1000).
# Batch size: 399 (Waiting for 601 more records to reach 1000).
# Batch size: 400 (Waiting for 600 more records to reach 1000).
# Batch size: 401 (Waiting for 599 more records to reach 1000).
# Batch size: 402 (Waiting for 598 more records to reach 1000).
# Batch size: 403 (Waiting for 597 more records to reach 1000).
# Batch size: 404 (Waiting for 596 more records to reach 1000).
# Batch size: 405 (Waiting for 595 more records to reach 1000).
# Batch size: 406 (Waiting for 594 more records to reach 1000).
# Batch size: 407 (Waiting for 593 more records to reach 1000).
# Batch size: 408 (Waiting for 592 more records to reach 1000).
# Batch size: 409 (Waiting for 591 more records to reach 1000).
# Batch size: 410 (Waiting for 590 more records to reach 1000).
# Batch size: 411 (Waiting for 589 more records to reach 1000).
# Batch size: 412 (Waiting for 588 more records to reach 1000).
# Batch size: 413 (Waiting for 587 more records to reach 1000).
# Batch size: 414 (Waiting for 586 more records to reach 1000).
# Batch size: 415 (Waiting for 585 more records to reach 1000).
# Batch size: 416 (Waiting for 584 more records to reach 1000).
# Batch size: 417 (Waiting for 583 more records to reach 1000).
# Batch size: 418 (Waiting for 582 more records to reach 1000).
# Batch size: 419 (Waiting for 581 more records to reach 1000).
# Batch size: 420 (Waiting for 580 more records to reach 1000).
# Batch size: 421 (Waiting for 579 more records to reach 1000).
# Batch size: 422 (Waiting for 578 more records to reach 1000).
# Batch size: 423 (Waiting for 577 more records to reach 1000).
# Batch size: 424 (Waiting for 576 more records to reach 1000).
# Batch size: 425 (Waiting for 575 more records to reach 1000).
# Batch size: 426 (Waiting for 574 more records to reach 1000).
# Batch size: 427 (Waiting for 573 more records to reach 1000).
# Batch size: 428 (Waiting for 572 more records to reach 1000).
# Batch size: 429 (Waiting for 571 more records to reach 1000).
# Batch size: 430 (Waiting for 570 more records to reach 1000).
# Batch size: 431 (Waiting for 569 more records to reach 1000).
# Batch size: 432 (Waiting for 568 more records to reach 1000).
# Batch size: 433 (Waiting for 567 more records to reach 1000).
# Batch size: 434 (Waiting for 566 more records to reach 1000).
# Batch size: 435 (Waiting for 565 more records to reach 1000).
# Batch size: 436 (Waiting for 564 more records to reach 1000).
# Batch size: 437 (Waiting for 563 more records to reach 1000).
# Batch size: 438 (Waiting for 562 more records to reach 1000).
# Batch size: 439 (Waiting for 561 more records to reach 1000).
# Batch size: 440 (Waiting for 560 more records to reach 1000).
# Batch size: 441 (Waiting for 559 more records to reach 1000).
# Batch size: 442 (Waiting for 558 more records to reach 1000).
# Batch size: 443 (Waiting for 557 more records to reach 1000).
# Batch size: 444 (Waiting for 556 more records to reach 1000).
# Batch size: 445 (Waiting for 555 more records to reach 1000).
# Batch size: 446 (Waiting for 554 more records to reach 1000).
# Batch size: 447 (Waiting for 553 more records to reach 1000).
# Batch size: 448 (Waiting for 552 more records to reach 1000).
# Batch size: 449 (Waiting for 551 more records to reach 1000).
# Batch size: 450 (Waiting for 550 more records to reach 1000).
# Batch size: 451 (Waiting for 549 more records to reach 1000).
# Batch size: 452 (Waiting for 548 more records to reach 1000).
# Batch size: 453 (Waiting for 547 more records to reach 1000).
# Batch size: 454 (Waiting for 546 more records to reach 1000).
# Batch size: 455 (Waiting for 545 more records to reach 1000).
# Batch size: 456 (Waiting for 544 more records to reach 1000).
# Batch size: 457 (Waiting for 543 more records to reach 1000).
# Batch size: 458 (Waiting for 542 more records to reach 1000).
# Batch size: 459 (Waiting for 541 more records to reach 1000).
# Batch size: 460 (Waiting for 540 more records to reach 1000).
# Batch size: 461 (Waiting for 539 more records to reach 1000).
# Batch size: 462 (Waiting for 538 more records to reach 1000).
# Batch size: 463 (Waiting for 537 more records to reach 1000).
# Batch size: 464 (Waiting for 536 more records to reach 1000).
# Batch size: 465 (Waiting for 535 more records to reach 1000).
# Batch size: 466 (Waiting for 534 more records to reach 1000).
# Batch size: 467 (Waiting for 533 more records to reach 1000).
# Batch size: 468 (Waiting for 532 more records to reach 1000).
# Batch size: 469 (Waiting for 531 more records to reach 1000).
# Batch size: 470 (Waiting for 530 more records to reach 1000).
# Batch size: 471 (Waiting for 529 more records to reach 1000).
# Batch size: 472 (Waiting for 528 more records to reach 1000).
# Batch size: 473 (Waiting for 527 more records to reach 1000).
# Batch size: 474 (Waiting for 526 more records to reach 1000).
# Batch size: 475 (Waiting for 525 more records to reach 1000).
# Batch size: 476 (Waiting for 524 more records to reach 1000).
# Batch size: 477 (Waiting for 523 more records to reach 1000).
# Batch size: 478 (Waiting for 522 more records to reach 1000).
# Batch size: 479 (Waiting for 521 more records to reach 1000).
# Batch size: 480 (Waiting for 520 more records to reach 1000).
# Batch size: 481 (Waiting for 519 more records to reach 1000).
# Batch size: 482 (Waiting for 518 more records to reach 1000).
# Batch size: 483 (Waiting for 517 more records to reach 1000).
# Batch size: 484 (Waiting for 516 more records to reach 1000).
# Batch size: 485 (Waiting for 515 more records to reach 1000).
# Batch size: 486 (Waiting for 514 more records to reach 1000).
# Batch size: 487 (Waiting for 513 more records to reach 1000).
# Batch size: 488 (Waiting for 512 more records to reach 1000).
# Batch size: 489 (Waiting for 511 more records to reach 1000).
# Batch size: 490 (Waiting for 510 more records to reach 1000).
# Batch size: 491 (Waiting for 509 more records to reach 1000).
# Batch size: 492 (Waiting for 508 more records to reach 1000).
# Batch size: 493 (Waiting for 507 more records to reach 1000).
# Batch size: 494 (Waiting for 506 more records to reach 1000).
# Batch size: 495 (Waiting for 505 more records to reach 1000).
# Batch size: 496 (Waiting for 504 more records to reach 1000).
# Batch size: 497 (Waiting for 503 more records to reach 1000).
# Batch size: 498 (Waiting for 502 more records to reach 1000).
# Batch size: 499 (Waiting for 501 more records to reach 1000).
# Batch size: 500 (Waiting for 500 more records to reach 1000).
# Batch size: 501 (Waiting for 499 more records to reach 1000).
# Batch size: 502 (Waiting for 498 more records to reach 1000).
# Batch size: 503 (Waiting for 497 more records to reach 1000).
# Batch size: 504 (Waiting for 496 more records to reach 1000).
# Batch size: 505 (Waiting for 495 more records to reach 1000).
# Batch size: 506 (Waiting for 494 more records to reach 1000).
# Batch size: 507 (Waiting for 493 more records to reach 1000).
# Batch size: 508 (Waiting for 492 more records to reach 1000).
# Batch size: 509 (Waiting for 491 more records to reach 1000).
# Batch size: 510 (Waiting for 490 more records to reach 1000).
# Batch size: 511 (Waiting for 489 more records to reach 1000).
# Batch size: 512 (Waiting for 488 more records to reach 1000).
# Batch size: 513 (Waiting for 487 more records to reach 1000).
# Batch size: 514 (Waiting for 486 more records to reach 1000).
# Batch size: 515 (Waiting for 485 more records to reach 1000).
# Batch size: 516 (Waiting for 484 more records to reach 1000).
# Batch size: 517 (Waiting for 483 more records to reach 1000).
# Batch size: 518 (Waiting for 482 more records to reach 1000).
# Batch size: 519 (Waiting for 481 more records to reach 1000).
# Batch size: 520 (Waiting for 480 more records to reach 1000).
# Batch size: 521 (Waiting for 479 more records to reach 1000).
# Batch size: 522 (Waiting for 478 more records to reach 1000).
# Batch size: 523 (Waiting for 477 more records to reach 1000).
# Batch size: 524 (Waiting for 476 more records to reach 1000).
# Batch size: 525 (Waiting for 475 more records to reach 1000).
# Batch size: 526 (Waiting for 474 more records to reach 1000).
# Batch size: 527 (Waiting for 473 more records to reach 1000).
# Batch size: 528 (Waiting for 472 more records to reach 1000).
# Batch size: 529 (Waiting for 471 more records to reach 1000).
# Batch size: 530 (Waiting for 470 more records to reach 1000).
# Batch size: 531 (Waiting for 469 more records to reach 1000).
# Batch size: 532 (Waiting for 468 more records to reach 1000).
# Batch size: 533 (Waiting for 467 more records to reach 1000).
# Batch size: 534 (Waiting for 466 more records to reach 1000).
# Batch size: 535 (Waiting for 465 more records to reach 1000).
# Batch size: 536 (Waiting for 464 more records to reach 1000).
# Batch size: 537 (Waiting for 463 more records to reach 1000).
# Batch size: 538 (Waiting for 462 more records to reach 1000).
# Batch size: 539 (Waiting for 461 more records to reach 1000).
# Batch size: 540 (Waiting for 460 more records to reach 1000).
# Batch size: 541 (Waiting for 459 more records to reach 1000).
# Batch size: 542 (Waiting for 458 more records to reach 1000).
# Batch size: 543 (Waiting for 457 more records to reach 1000).
# Batch size: 544 (Waiting for 456 more records to reach 1000).
# Batch size: 545 (Waiting for 455 more records to reach 1000).
# Batch size: 546 (Waiting for 454 more records to reach 1000).
# Batch size: 547 (Waiting for 453 more records to reach 1000).
# Batch size: 548 (Waiting for 452 more records to reach 1000).
# Batch size: 549 (Waiting for 451 more records to reach 1000).
# Batch size: 550 (Waiting for 450 more records to reach 1000).
# Batch size: 551 (Waiting for 449 more records to reach 1000).
# Batch size: 552 (Waiting for 448 more records to reach 1000).
# Batch size: 553 (Waiting for 447 more records to reach 1000).
# Batch size: 554 (Waiting for 446 more records to reach 1000).
# Batch size: 555 (Waiting for 445 more records to reach 1000).
# Batch size: 556 (Waiting for 444 more records to reach 1000).
# Batch size: 557 (Waiting for 443 more records to reach 1000).
# Batch size: 558 (Waiting for 442 more records to reach 1000).
# Batch size: 559 (Waiting for 441 more records to reach 1000).
# Batch size: 560 (Waiting for 440 more records to reach 1000).
# Batch size: 561 (Waiting for 439 more records to reach 1000).
# Batch size: 562 (Waiting for 438 more records to reach 1000).
# Batch size: 563 (Waiting for 437 more records to reach 1000).
# Batch size: 564 (Waiting for 436 more records to reach 1000).
# Batch size: 565 (Waiting for 435 more records to reach 1000).
# Batch size: 566 (Waiting for 434 more records to reach 1000).
# Batch size: 567 (Waiting for 433 more records to reach 1000).
# Batch size: 568 (Waiting for 432 more records to reach 1000).
# Batch size: 569 (Waiting for 431 more records to reach 1000).
# Batch size: 570 (Waiting for 430 more records to reach 1000).
# Batch size: 571 (Waiting for 429 more records to reach 1000).
# Batch size: 572 (Waiting for 428 more records to reach 1000).
# Batch size: 573 (Waiting for 427 more records to reach 1000).
# Batch size: 574 (Waiting for 426 more records to reach 1000).
# Batch size: 575 (Waiting for 425 more records to reach 1000).
# Batch size: 576 (Waiting for 424 more records to reach 1000).
# Batch size: 577 (Waiting for 423 more records to reach 1000).
# Batch size: 578 (Waiting for 422 more records to reach 1000).
# Batch size: 579 (Waiting for 421 more records to reach 1000).
# Batch size: 580 (Waiting for 420 more records to reach 1000).
# Batch size: 581 (Waiting for 419 more records to reach 1000).
# Batch size: 582 (Waiting for 418 more records to reach 1000).
# Batch size: 583 (Waiting for 417 more records to reach 1000).
# Batch size: 584 (Waiting for 416 more records to reach 1000).
# Batch size: 585 (Waiting for 415 more records to reach 1000).
# Batch size: 586 (Waiting for 414 more records to reach 1000).
# Batch size: 587 (Waiting for 413 more records to reach 1000).
# Batch size: 588 (Waiting for 412 more records to reach 1000).
# Batch size: 589 (Waiting for 411 more records to reach 1000).
# Batch size: 590 (Waiting for 410 more records to reach 1000).
# Batch size: 591 (Waiting for 409 more records to reach 1000).
# Batch size: 592 (Waiting for 408 more records to reach 1000).
# Batch size: 593 (Waiting for 407 more records to reach 1000).
# Batch size: 594 (Waiting for 406 more records to reach 1000).
# Batch size: 595 (Waiting for 405 more records to reach 1000).
# Batch size: 596 (Waiting for 404 more records to reach 1000).
# Batch size: 597 (Waiting for 403 more records to reach 1000).
# Batch size: 598 (Waiting for 402 more records to reach 1000).
# Batch size: 599 (Waiting for 401 more records to reach 1000).
# Batch size: 600 (Waiting for 400 more records to reach 1000).
# Batch size: 601 (Waiting for 399 more records to reach 1000).
# Batch size: 602 (Waiting for 398 more records to reach 1000).
# Batch size: 603 (Waiting for 397 more records to reach 1000).
# Batch size: 604 (Waiting for 396 more records to reach 1000).
# Batch size: 605 (Waiting for 395 more records to reach 1000).
# Batch size: 606 (Waiting for 394 more records to reach 1000).
# Batch size: 607 (Waiting for 393 more records to reach 1000).
# Batch size: 608 (Waiting for 392 more records to reach 1000).
# Batch size: 609 (Waiting for 391 more records to reach 1000).
# Batch size: 610 (Waiting for 390 more records to reach 1000).
# Batch size: 611 (Waiting for 389 more records to reach 1000).
# Batch size: 612 (Waiting for 388 more records to reach 1000).
# Batch size: 613 (Waiting for 387 more records to reach 1000).
# Batch size: 614 (Waiting for 386 more records to reach 1000).
# Batch size: 615 (Waiting for 385 more records to reach 1000).
# Batch size: 616 (Waiting for 384 more records to reach 1000).
# Batch size: 617 (Waiting for 383 more records to reach 1000).
# Batch size: 618 (Waiting for 382 more records to reach 1000).
# Batch size: 619 (Waiting for 381 more records to reach 1000).
# Batch size: 620 (Waiting for 380 more records to reach 1000).
# Batch size: 621 (Waiting for 379 more records to reach 1000).
# Batch size: 622 (Waiting for 378 more records to reach 1000).
# Batch size: 623 (Waiting for 377 more records to reach 1000).
# Batch size: 624 (Waiting for 376 more records to reach 1000).
# Batch size: 625 (Waiting for 375 more records to reach 1000).
# Batch size: 626 (Waiting for 374 more records to reach 1000).
# Batch size: 627 (Waiting for 373 more records to reach 1000).
# Batch size: 628 (Waiting for 372 more records to reach 1000).
# Batch size: 629 (Waiting for 371 more records to reach 1000).
# Batch size: 630 (Waiting for 370 more records to reach 1000).
# Batch size: 631 (Waiting for 369 more records to reach 1000).
# Batch size: 632 (Waiting for 368 more records to reach 1000).
# Batch size: 633 (Waiting for 367 more records to reach 1000).
# Batch size: 634 (Waiting for 366 more records to reach 1000).
# Batch size: 635 (Waiting for 365 more records to reach 1000).
# Batch size: 636 (Waiting for 364 more records to reach 1000).
# Batch size: 637 (Waiting for 363 more records to reach 1000).
# Batch size: 638 (Waiting for 362 more records to reach 1000).
# Batch size: 639 (Waiting for 361 more records to reach 1000).
# Batch size: 640 (Waiting for 360 more records to reach 1000).
# Batch size: 641 (Waiting for 359 more records to reach 1000).
# Batch size: 642 (Waiting for 358 more records to reach 1000).
# Batch size: 643 (Waiting for 357 more records to reach 1000).
# Batch size: 644 (Waiting for 356 more records to reach 1000).
# Batch size: 645 (Waiting for 355 more records to reach 1000).
# Batch size: 646 (Waiting for 354 more records to reach 1000).
# Batch size: 647 (Waiting for 353 more records to reach 1000).
# Batch size: 648 (Waiting for 352 more records to reach 1000).
# Batch size: 649 (Waiting for 351 more records to reach 1000).
# Batch size: 650 (Waiting for 350 more records to reach 1000).
# Batch size: 651 (Waiting for 349 more records to reach 1000).
# Batch size: 652 (Waiting for 348 more records to reach 1000).
# Batch size: 653 (Waiting for 347 more records to reach 1000).
# Batch size: 654 (Waiting for 346 more records to reach 1000).
# Batch size: 655 (Waiting for 345 more records to reach 1000).
# Batch size: 656 (Waiting for 344 more records to reach 1000).
# Batch size: 657 (Waiting for 343 more records to reach 1000).
# Batch size: 658 (Waiting for 342 more records to reach 1000).
# Batch size: 659 (Waiting for 341 more records to reach 1000).
# Batch size: 660 (Waiting for 340 more records to reach 1000).
# Batch size: 661 (Waiting for 339 more records to reach 1000).
# Batch size: 662 (Waiting for 338 more records to reach 1000).
# Batch size: 663 (Waiting for 337 more records to reach 1000).
# Batch size: 664 (Waiting for 336 more records to reach 1000).
# Batch size: 665 (Waiting for 335 more records to reach 1000).
# Batch size: 666 (Waiting for 334 more records to reach 1000).
# Batch size: 667 (Waiting for 333 more records to reach 1000).
# Batch size: 668 (Waiting for 332 more records to reach 1000).
# Batch size: 669 (Waiting for 331 more records to reach 1000).
# Batch size: 670 (Waiting for 330 more records to reach 1000).
# Batch size: 671 (Waiting for 329 more records to reach 1000).
# Batch size: 672 (Waiting for 328 more records to reach 1000).
# Batch size: 673 (Waiting for 327 more records to reach 1000).
# Batch size: 674 (Waiting for 326 more records to reach 1000).
# Batch size: 675 (Waiting for 325 more records to reach 1000).
# Batch size: 676 (Waiting for 324 more records to reach 1000).
# Batch size: 677 (Waiting for 323 more records to reach 1000).
# Batch size: 678 (Waiting for 322 more records to reach 1000).
# Batch size: 679 (Waiting for 321 more records to reach 1000).
# Batch size: 680 (Waiting for 320 more records to reach 1000).
# Batch size: 681 (Waiting for 319 more records to reach 1000).
# Batch size: 682 (Waiting for 318 more records to reach 1000).
# Batch size: 683 (Waiting for 317 more records to reach 1000).
# Batch size: 684 (Waiting for 316 more records to reach 1000).
# Batch size: 685 (Waiting for 315 more records to reach 1000).
# Batch size: 686 (Waiting for 314 more records to reach 1000).
# Batch size: 687 (Waiting for 313 more records to reach 1000).
# Batch size: 688 (Waiting for 312 more records to reach 1000).
# Batch size: 689 (Waiting for 311 more records to reach 1000).
# Batch size: 690 (Waiting for 310 more records to reach 1000).
# Batch size: 691 (Waiting for 309 more records to reach 1000).
# Batch size: 692 (Waiting for 308 more records to reach 1000).
# Batch size: 693 (Waiting for 307 more records to reach 1000).
# Batch size: 694 (Waiting for 306 more records to reach 1000).
# Batch size: 695 (Waiting for 305 more records to reach 1000).
# Batch size: 696 (Waiting for 304 more records to reach 1000).
# Batch size: 697 (Waiting for 303 more records to reach 1000).
# Batch size: 698 (Waiting for 302 more records to reach 1000).
# Batch size: 699 (Waiting for 301 more records to reach 1000).
# Batch size: 700 (Waiting for 300 more records to reach 1000).
# Batch size: 701 (Waiting for 299 more records to reach 1000).
# Batch size: 702 (Waiting for 298 more records to reach 1000).
# Batch size: 703 (Waiting for 297 more records to reach 1000).
# Batch size: 704 (Waiting for 296 more records to reach 1000).
# Batch size: 705 (Waiting for 295 more records to reach 1000).
# Batch size: 706 (Waiting for 294 more records to reach 1000).
# Batch size: 707 (Waiting for 293 more records to reach 1000).
# Batch size: 708 (Waiting for 292 more records to reach 1000).
# Batch size: 709 (Waiting for 291 more records to reach 1000).
# Batch size: 710 (Waiting for 290 more records to reach 1000).
# Batch size: 711 (Waiting for 289 more records to reach 1000).
# Batch size: 712 (Waiting for 288 more records to reach 1000).
# Batch size: 713 (Waiting for 287 more records to reach 1000).
# Batch size: 714 (Waiting for 286 more records to reach 1000).
# Batch size: 715 (Waiting for 285 more records to reach 1000).
# Batch size: 716 (Waiting for 284 more records to reach 1000).
# Batch size: 717 (Waiting for 283 more records to reach 1000).
# Batch size: 718 (Waiting for 282 more records to reach 1000).
# Batch size: 719 (Waiting for 281 more records to reach 1000).
# Batch size: 720 (Waiting for 280 more records to reach 1000).
# Batch size: 721 (Waiting for 279 more records to reach 1000).
# Batch size: 722 (Waiting for 278 more records to reach 1000).
# Batch size: 723 (Waiting for 277 more records to reach 1000).
# Batch size: 724 (Waiting for 276 more records to reach 1000).
# Batch size: 725 (Waiting for 275 more records to reach 1000).
# Batch size: 726 (Waiting for 274 more records to reach 1000).
# Batch size: 727 (Waiting for 273 more records to reach 1000).
# Batch size: 728 (Waiting for 272 more records to reach 1000).
# Batch size: 729 (Waiting for 271 more records to reach 1000).
# Batch size: 730 (Waiting for 270 more records to reach 1000).
# Batch size: 731 (Waiting for 269 more records to reach 1000).
# Batch size: 732 (Waiting for 268 more records to reach 1000).
# Batch size: 733 (Waiting for 267 more records to reach 1000).
# Batch size: 734 (Waiting for 266 more records to reach 1000).
# Batch size: 735 (Waiting for 265 more records to reach 1000).
# Batch size: 736 (Waiting for 264 more records to reach 1000).
# Batch size: 737 (Waiting for 263 more records to reach 1000).
# Batch size: 738 (Waiting for 262 more records to reach 1000).
# Batch size: 739 (Waiting for 261 more records to reach 1000).
# Batch size: 740 (Waiting for 260 more records to reach 1000).
# Batch size: 741 (Waiting for 259 more records to reach 1000).
# Batch size: 742 (Waiting for 258 more records to reach 1000).
# Batch size: 743 (Waiting for 257 more records to reach 1000).
# Batch size: 744 (Waiting for 256 more records to reach 1000).
# Batch size: 745 (Waiting for 255 more records to reach 1000).
# Batch size: 746 (Waiting for 254 more records to reach 1000).
# Batch size: 747 (Waiting for 253 more records to reach 1000).
# Batch size: 748 (Waiting for 252 more records to reach 1000).
# Batch size: 749 (Waiting for 251 more records to reach 1000).
# Batch size: 750 (Waiting for 250 more records to reach 1000).
# Batch size: 751 (Waiting for 249 more records to reach 1000).
# Batch size: 752 (Waiting for 248 more records to reach 1000).
# Batch size: 753 (Waiting for 247 more records to reach 1000).
# Batch size: 754 (Waiting for 246 more records to reach 1000).
# Batch size: 755 (Waiting for 245 more records to reach 1000).
# Batch size: 756 (Waiting for 244 more records to reach 1000).
# Batch size: 757 (Waiting for 243 more records to reach 1000).
# Batch size: 758 (Waiting for 242 more records to reach 1000).
# Batch size: 759 (Waiting for 241 more records to reach 1000).
# Batch size: 760 (Waiting for 240 more records to reach 1000).
# Batch size: 761 (Waiting for 239 more records to reach 1000).
# Batch size: 762 (Waiting for 238 more records to reach 1000).
# Batch size: 763 (Waiting for 237 more records to reach 1000).
# Batch size: 764 (Waiting for 236 more records to reach 1000).
# Batch size: 765 (Waiting for 235 more records to reach 1000).
# Batch size: 766 (Waiting for 234 more records to reach 1000).
# Batch size: 767 (Waiting for 233 more records to reach 1000).
# Batch size: 768 (Waiting for 232 more records to reach 1000).
# Batch size: 769 (Waiting for 231 more records to reach 1000).
# Batch size: 770 (Waiting for 230 more records to reach 1000).
# Batch size: 771 (Waiting for 229 more records to reach 1000).
# Batch size: 772 (Waiting for 228 more records to reach 1000).
# Batch size: 773 (Waiting for 227 more records to reach 1000).
# Batch size: 774 (Waiting for 226 more records to reach 1000).
# Batch size: 775 (Waiting for 225 more records to reach 1000).
# ...
# Batch size: 352 (Waiting for 648 more records to reach 1000).
# Batch size: 353 (Waiting for 647 more records to reach 1000).
# Batch size: 354 (Waiting for 646 more records to reach 1000).
# Batch size: 355 (Waiting for 645 more records to reach 1000).
# Batch size: 356 (Waiting for 644 more records to reach 1000).
# Batch size: 357 (Waiting for 643 more records to reach 1000).
# Batch size: 358 (Waiting for 642 more records to reach 1000).
# Batch size: 359 (Waiting for 641 more records to reach 1000).
# Batch size: 360 (Waiting for 640 more records to reach 1000).
# Batch size: 361 (Waiting for 639 more records to reach 1000).
# Batch size: 362 (Waiting for 638 more records to reach 1000).
# Batch size: 363 (Waiting for 637 more records to reach 1000).
# Batch size: 364 (Waiting for 636 more records to reach 1000).
# Batch size: 365 (Waiting for 635 more records to reach 1000).
# Batch size: 366 (Waiting for 634 more records to reach 1000).
# Batch size: 367 (Waiting for 633 more records to reach 1000).
# Batch size: 368 (Waiting for 632 more records to reach 1000).
# Batch size: 369 (Waiting for 631 more records to reach 1000).
# Batch size: 370 (Waiting for 630 more records to reach 1000).
# Batch size: 371 (Waiting for 629 more records to reach 1000).
# Batch size: 372 (Waiting for 628 more records to reach 1000).
# Batch size: 373 (Waiting for 627 more records to reach 1000).
# Batch size: 374 (Waiting for 626 more records to reach 1000).
# Batch size: 375 (Waiting for 625 more records to reach 1000).
# Batch size: 376 (Waiting for 624 more records to reach 1000).
# Batch size: 377 (Waiting for 623 more records to reach 1000).
# Batch size: 378 (Waiting for 622 more records to reach 1000).
# Batch size: 379 (Waiting for 621 more records to reach 1000).
# Batch size: 380 (Waiting for 620 more records to reach 1000).
# Batch size: 381 (Waiting for 619 more records to reach 1000).
# Batch size: 382 (Waiting for 618 more records to reach 1000).
# Batch size: 383 (Waiting for 617 more records to reach 1000).
# Batch size: 384 (Waiting for 616 more records to reach 1000).
# Batch size: 385 (Waiting for 615 more records to reach 1000).
# Batch size: 386 (Waiting for 614 more records to reach 1000).
# Batch size: 387 (Waiting for 613 more records to reach 1000).
# Batch size: 388 (Waiting for 612 more records to reach 1000).
# Batch size: 389 (Waiting for 611 more records to reach 1000).
# Batch size: 390 (Waiting for 610 more records to reach 1000).
# Batch size: 391 (Waiting for 609 more records to reach 1000).
# Batch size: 392 (Waiting for 608 more records to reach 1000).
# Batch size: 393 (Waiting for 607 more records to reach 1000).
# Batch size: 394 (Waiting for 606 more records to reach 1000).
# Batch size: 395 (Waiting for 605 more records to reach 1000).
# Batch size: 396 (Waiting for 604 more records to reach 1000).
# Batch size: 397 (Waiting for 603 more records to reach 1000).
# Batch size: 398 (Waiting for 602 more records to reach 1000).
# Batch size: 399 (Waiting for 601 more records to reach 1000).
# Batch size: 400 (Waiting for 600 more records to reach 1000).
# Batch size: 401 (Waiting for 599 more records to reach 1000).
# Batch size: 402 (Waiting for 598 more records to reach 1000).
# Batch size: 403 (Waiting for 597 more records to reach 1000).
# Batch size: 404 (Waiting for 596 more records to reach 1000).
# Batch size: 405 (Waiting for 595 more records to reach 1000).
# Batch size: 406 (Waiting for 594 more records to reach 1000).
# Batch size: 407 (Waiting for 593 more records to reach 1000).
# Batch size: 408 (Waiting for 592 more records to reach 1000).
# Batch size: 409 (Waiting for 591 more records to reach 1000).
# Batch size: 410 (Waiting for 590 more records to reach 1000).
# Batch size: 411 (Waiting for 589 more records to reach 1000).
# Batch size: 412 (Waiting for 588 more records to reach 1000).
# Batch size: 413 (Waiting for 587 more records to reach 1000).
# Batch size: 414 (Waiting for 586 more records to reach 1000).
# Batch size: 415 (Waiting for 585 more records to reach 1000).
# Batch size: 416 (Waiting for 584 more records to reach 1000).
# Batch size: 417 (Waiting for 583 more records to reach 1000).
# Batch size: 418 (Waiting for 582 more records to reach 1000).
# Batch size: 419 (Waiting for 581 more records to reach 1000).
# Batch size: 420 (Waiting for 580 more records to reach 1000).
# Batch size: 421 (Waiting for 579 more records to reach 1000).
# Batch size: 422 (Waiting for 578 more records to reach 1000).
# Batch size: 423 (Waiting for 577 more records to reach 1000).
# Batch size: 424 (Waiting for 576 more records to reach 1000).
# Batch size: 425 (Waiting for 575 more records to reach 1000).
# Batch size: 426 (Waiting for 574 more records to reach 1000).
# Batch size: 427 (Waiting for 573 more records to reach 1000).
# Batch size: 428 (Waiting for 572 more records to reach 1000).
# Batch size: 429 (Waiting for 571 more records to reach 1000).
# Batch size: 430 (Waiting for 570 more records to reach 1000).
# Batch size: 431 (Waiting for 569 more records to reach 1000).
# Batch size: 432 (Waiting for 568 more records to reach 1000).
# Batch size: 433 (Waiting for 567 more records to reach 1000).
# Batch size: 434 (Waiting for 566 more records to reach 1000).
# Batch size: 435 (Waiting for 565 more records to reach 1000).
# Batch size: 436 (Waiting for 564 more records to reach 1000).
# Batch size: 437 (Waiting for 563 more records to reach 1000).
# Batch size: 438 (Waiting for 562 more records to reach 1000).
# Batch size: 439 (Waiting for 561 more records to reach 1000).
# Batch size: 440 (Waiting for 560 more records to reach 1000).
# Batch size: 441 (Waiting for 559 more records to reach 1000).
# Batch size: 442 (Waiting for 558 more records to reach 1000).
# Batch size: 443 (Waiting for 557 more records to reach 1000).
# Batch size: 444 (Waiting for 556 more records to reach 1000).
# Batch size: 445 (Waiting for 555 more records to reach 1000).
# Batch size: 446 (Waiting for 554 more records to reach 1000).
# Batch size: 447 (Waiting for 553 more records to reach 1000).
# Batch size: 448 (Waiting for 552 more records to reach 1000).
# Batch size: 449 (Waiting for 551 more records to reach 1000).
# Batch size: 450 (Waiting for 550 more records to reach 1000).
# Batch size: 451 (Waiting for 549 more records to reach 1000).
# Batch size: 452 (Waiting for 548 more records to reach 1000).
# Batch size: 453 (Waiting for 547 more records to reach 1000).
# Batch size: 454 (Waiting for 546 more records to reach 1000).
# Batch size: 455 (Waiting for 545 more records to reach 1000).
# Batch size: 456 (Waiting for 544 more records to reach 1000).
# Batch size: 457 (Waiting for 543 more records to reach 1000).
# Batch size: 458 (Waiting for 542 more records to reach 1000).
# Batch size: 459 (Waiting for 541 more records to reach 1000).
# Batch size: 460 (Waiting for 540 more records to reach 1000).
# Batch size: 461 (Waiting for 539 more records to reach 1000).
# Batch size: 462 (Waiting for 538 more records to reach 1000).
# Batch size: 463 (Waiting for 537 more records to reach 1000).
# Batch size: 464 (Waiting for 536 more records to reach 1000).
# Batch size: 465 (Waiting for 535 more records to reach 1000).
# Batch size: 466 (Waiting for 534 more records to reach 1000).
# Batch size: 467 (Waiting for 533 more records to reach 1000).
# Batch size: 468 (Waiting for 532 more records to reach 1000).
# Batch size: 469 (Waiting for 531 more records to reach 1000).
# Batch size: 470 (Waiting for 530 more records to reach 1000).
# Batch size: 471 (Waiting for 529 more records to reach 1000).
# Batch size: 472 (Waiting for 528 more records to reach 1000).
# Batch size: 473 (Waiting for 527 more records to reach 1000).
# Batch size: 474 (Waiting for 526 more records to reach 1000).
# Batch size: 475 (Waiting for 525 more records to reach 1000).
# Batch size: 476 (Waiting for 524 more records to reach 1000).
# Batch size: 477 (Waiting for 523 more records to reach 1000).
# Batch size: 478 (Waiting for 522 more records to reach 1000).
# Batch size: 479 (Waiting for 521 more records to reach 1000).
# Batch size: 480 (Waiting for 520 more records to reach 1000).
# Batch size: 481 (Waiting for 519 more records to reach 1000).
# Batch size: 482 (Waiting for 518 more records to reach 1000).
# Batch size: 483 (Waiting for 517 more records to reach 1000).
# Batch size: 484 (Waiting for 516 more records to reach 1000).
# Batch size: 485 (Waiting for 515 more records to reach 1000).
# Batch size: 486 (Waiting for 514 more records to reach 1000).
# Batch size: 487 (Waiting for 513 more records to reach 1000).
# Batch size: 488 (Waiting for 512 more records to reach 1000).
# Batch size: 489 (Waiting for 511 more records to reach 1000).
# Batch size: 490 (Waiting for 510 more records to reach 1000).
# Batch size: 491 (Waiting for 509 more records to reach 1000).
# Batch size: 492 (Waiting for 508 more records to reach 1000).
# Batch size: 493 (Waiting for 507 more records to reach 1000).
# Batch size: 494 (Waiting for 506 more records to reach 1000).
# Batch size: 495 (Waiting for 505 more records to reach 1000).
# Batch size: 496 (Waiting for 504 more records to reach 1000).
# Batch size: 497 (Waiting for 503 more records to reach 1000).
# Batch size: 498 (Waiting for 502 more records to reach 1000).
# Batch size: 499 (Waiting for 501 more records to reach 1000).
# Batch size: 500 (Waiting for 500 more records to reach 1000).
# Batch size: 501 (Waiting for 499 more records to reach 1000).
# Batch size: 502 (Waiting for 498 more records to reach 1000).
# Batch size: 503 (Waiting for 497 more records to reach 1000).
# Batch size: 504 (Waiting for 496 more records to reach 1000).
# Batch size: 505 (Waiting for 495 more records to reach 1000).
# Batch size: 506 (Waiting for 494 more records to reach 1000).
# Batch size: 507 (Waiting for 493 more records to reach 1000).
# Batch size: 508 (Waiting for 492 more records to reach 1000).
# Batch size: 509 (Waiting for 491 more records to reach 1000).
# Batch size: 510 (Waiting for 490 more records to reach 1000).
# Batch size: 511 (Waiting for 489 more records to reach 1000).
# Batch size: 512 (Waiting for 488 more records to reach 1000).
# Batch size: 513 (Waiting for 487 more records to reach 1000).
# Batch size: 514 (Waiting for 486 more records to reach 1000).
# Batch size: 515 (Waiting for 485 more records to reach 1000).
# Batch size: 516 (Waiting for 484 more records to reach 1000).
# Batch size: 517 (Waiting for 483 more records to reach 1000).
# Batch size: 518 (Waiting for 482 more records to reach 1000).
# Batch size: 519 (Waiting for 481 more records to reach 1000).
# Batch size: 520 (Waiting for 480 more records to reach 1000).
# Batch size: 521 (Waiting for 479 more records to reach 1000).
# Batch size: 522 (Waiting for 478 more records to reach 1000).
# Batch size: 523 (Waiting for 477 more records to reach 1000).
# Batch size: 524 (Waiting for 476 more records to reach 1000).
# Batch size: 525 (Waiting for 475 more records to reach 1000).
# Batch size: 526 (Waiting for 474 more records to reach 1000).
# Batch size: 527 (Waiting for 473 more records to reach 1000).
# Batch size: 528 (Waiting for 472 more records to reach 1000).
# Batch size: 529 (Waiting for 471 more records to reach 1000).
# Batch size: 530 (Waiting for 470 more records to reach 1000).
# Batch size: 531 (Waiting for 469 more records to reach 1000).
# Batch size: 532 (Waiting for 468 more records to reach 1000).
# Batch size: 533 (Waiting for 467 more records to reach 1000).
# Batch size: 534 (Waiting for 466 more records to reach 1000).
# Batch size: 535 (Waiting for 465 more records to reach 1000).
# Batch size: 536 (Waiting for 464 more records to reach 1000).
# Batch size: 537 (Waiting for 463 more records to reach 1000).
# Batch size: 538 (Waiting for 462 more records to reach 1000).
# Batch size: 539 (Waiting for 461 more records to reach 1000).
# Batch size: 540 (Waiting for 460 more records to reach 1000).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      27         df.to_csv(file_name, mode='w', header=True, index=False)
#      29 # Loop untuk mengonsumsi data dari Kafka
# ---> 30 for message in consumer:
#      31     # Menambahkan data pesan yang diterima ke dalam batch
#      32     batch_data.append(json.loads(message.value))
#      34     # Debug: Print ukuran batch yang telah terisi
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\site-packages\kafka\consumer\group.py:1197, in KafkaConsumer.__next__(self)
#    1195     return self.next_v1()
#    1196 else:
# -> 1197     return self.next_v2()
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\site-packages\kafka\consumer\group.py:1205, in KafkaConsumer.next_v2(self)
#    1203     self._iterator = self._message_generator_v2()
#    1204 try:
# -> 1205     return next(self._iterator)
#    1206 except StopIteration:
#    1207     self._iterator = None
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\site-packages\kafka\consumer\group.py:1120, in KafkaConsumer._message_generator_v2(self)
#    1118 def _message_generator_v2(self):
#    1119     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1120     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1121     for tp, records in six.iteritems(record_map):
#    1122         # Generators are stateful, and it is possible that the tp / records
#    1123         # here may become stale during iteration -- i.e., we seek to a
#    1124         # different offset, pause consumption, or lose assignment.
#    1125         for record in records:
#    1126             # is_fetchable(tp) should handle assignment changes and offset
#    1127             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1128             # outer function destroying the existing iterator/generator
#    1129             # via self._iterator = None
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\site-packages\kafka\consumer\group.py:657, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     655 remaining = timeout_ms
#     656 while not self._closed:
# --> 657     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     658     if records:
#     659         return records
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\site-packages\kafka\consumer\group.py:706, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     703     self._client.poll(timeout_ms=0)
#     705 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 706 self._client.poll(timeout_ms=timeout_ms)
#     707 # after the long poll, we should check whether the group needs to rebalance
#     708 # prior to returning data so that the group can stabilize faster
#     709 if self._coordinator.need_rejoin():
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File c:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
from pyspark.sql import SparkSession
from pyspark.ml.recommendation import ALS
from pyspark.sql.functions import col

# Inisialisasi Spark Session
spark = SparkSession.builder.appName("BigDataModelTraining").getOrCreate()

# Membaca data dari CSV (asumsikan data sudah disimpan dalam file)
df = spark.read.csv('batch_data.csv', header=True, inferSchema=True)

# Skema (a) Membagi Data ke 3 bagian berdasarkan waktu atau jumlah data
total_rows = df.count()
split1 = total_rows // 3
split2 = 2 * (total_rows // 3)

# Membagi data menjadi 3 bagian
df_part1 = df.limit(split1)  # Model 1: Data 1/3 pertama
df_part2 = df.limit(split2).subtract(df_part1)  # Model 2: Data 1/3 kedua
df_part3 = df.subtract(df_part1).subtract(df_part2)  # Model 3: Data 1/3 terakhir

# Fungsi untuk melatih model menggunakan ALS
def train_als_model(data, rank=10, max_iter=5, reg_param=0.1):
    als = ALS(userCol="user_id", itemCol="product_id", ratingCol="price", rank=rank, maxIter=max_iter, regParam=reg_param)
    model = als.fit(data)
    return model

# Latih model untuk masing-masing bagian
model1 = train_als_model(df_part1)
model2 = train_als_model(df_part1.union(df_part2))
model3 = train_als_model(df_part1.union(df_part2).union(df_part3))

# Simpan model
model1.save("model1")
model2.save("model2")
model3.save("model3")

# Stop Spark session
spark.stop()

# %%
import os
os.environ["PYSPARK_DRIVER_PYTHON"] = "python3.10.0"  # Or the full path to the Python executable

# %%
from flask import Flask, request, jsonify
from pyspark.ml.recommendation import ALSModel
from pyspark.sql import SparkSession

# Inisialisasi Flask dan Spark
app = Flask(__name__)
spark = SparkSession.builder.appName("BigDataModelAPI").getOrCreate()

# Fungsi untuk memuat model
def load_model(model_name):
    return ALSModel.load(f"{model_name}")

# Load model-model yang telah disimpan
model1 = load_model("model1")
model2 = load_model("model2")
model3 = load_model("model3")

# Endpoint untuk rekomendasi (Model 1)
import logging
logging.getLogger('py4j').setLevel(logging.ERROR)

@app.route('/recommend_model1', methods=['POST'])
def recommend_model1():
    try:
        data = request.get_json()
        logging.debug(f"Received data: {data}")
        
        if not data or 'user_id' not in data:
            return jsonify({"error": "Missing 'user_id' in request data"}), 400
        
        user_id = data['user_id']
        logging.debug(f"Processing recommendation for user_id: {user_id}")
        
        # Prepare DataFrame and generate recommendations
        user_df = spark.createDataFrame([(user_id,)], ["user_id"])
        recommendations = model1.recommendForUserSubset(user_df, 5)
        recommendations_list = recommendations.collect()
        
        if len(recommendations_list) == 0:
            return jsonify({"message": f"No recommendations found for user_id {user_id}."}), 404
        
        recommendations_json = [{
            "user_id": rec.user_id,
            "recommendations": [r.product for r in rec.recommendations]
        } for rec in recommendations_list]
        
        return jsonify(recommendations_json)

    except Exception as e:
        logging.error(f"Error: {str(e)}")
        return jsonify({"error": str(e)}), 500

# Endpoint untuk rekomendasi (Model 2)
@app.route('/recommend_model2', methods=['POST'])
def recommend_model2():
    data = request.get_json()
    user_id = data['user_id']
    recommendations = model2.recommendForUserSubset(user_id, 5)  # Misalnya, rekomendasi 5 produk
    return jsonify(recommendations)

# Endpoint untuk rekomendasi (Model 3)
@app.route('/recommend_model3', methods=['POST'])
def recommend_model3():
    data = request.get_json()
    user_id = data['user_id']
    recommendations = model3.recommendForUserSubset(user_id, 5)  # Misalnya, rekomendasi 5 produk
    return jsonify(recommendations)

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# ERROR:root:Error: An error occurred while calling o713.collectToPython.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 217.0 failed 1 times, most recent failure: Lost task 0.0 in stage 217.0 (TID 624) (host.docker.internal executor driver): org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "C:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\Lib\site-packages\pyspark\python\lib\pyspark.zip\pyspark\worker.py", line 1100, in main
# pyspark.errors.exceptions.base.PySparkRuntimeError: [PYTHON_VERSION_MISMATCH] Python in worker has different version (3, 11) than that in driver 3.10, PySpark cannot run with different minor versions.
# Please check environment variables PYSPARK_PYTHON and PYSPARK_DRIVER_PYTHON are correctly set.
#
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.handlePythonException(PythonRunner.scala:572)
# 	at org.apache.spark.api.python.PythonRunner$$anon$3.read(PythonRunner.scala:784)
# 	at org.apache.spark.api.python.PythonRunner$$anon$3.read(PythonRunner.scala:766)
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:525)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:491)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage2.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.shuffle.sort.BypassMergeSortShuffleWriter.write(BypassMergeSortShuffleWriter.java:140)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.failJobAndIndependentStages(DAGScheduler.scala:2856)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2(DAGScheduler.scala:2792)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2$adapted(DAGScheduler.scala:2791)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:2791)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1(DAGScheduler.scala:1247)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1$adapted(DAGScheduler.scala:1247)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:1247)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:3060)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2994)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2983)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# Caused by: org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "C:\Users\dwiyasa\anaconda3\envs\GPU-CUDA\Lib\site-packages\pyspark\python\lib\pyspark.zip\pyspark\worker.py", line 1100, in main
# pyspark.errors.exceptions.base.PySparkRuntimeError: [PYTHON_VERSION_MISMATCH] Python in worker has different version (3, 11) than that in driver 3.10, PySpark cannot run with different minor versions.
# Please check environment variables PYSPARK_PYTHON and PYSPARK_DRIVER_PYTHON are correctly set.
#
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.handlePythonException(PythonRunner.scala:572)
# 	at org.apache.spark.api.python.PythonRunner$$anon$3.read(PythonRunner.scala:784)
# 	at org.apache.spark.api.python.PythonRunner$$anon$3.read(PythonRunner.scala:766)
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:525)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:491)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage2.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.shuffle.sort.BypassMergeSortShuffleWriter.write(BypassMergeSortShuffleWriter.java:140)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
#
# INFO:werkzeug:127.0.0.1 - - [10/Nov/2024 23:02:58] "POST /recommend_model1 HTTP/1.1" 500 -

# %%
import sys
print(f"Driver Python version: {sys.version}")

from pyspark import SparkContext
print(f"Worker Python version: {SparkContext.getOrCreate().pythonVer}")
# Out:
# 3.10.0 | packaged by conda-forge | (default, Nov 10 2021, 13:20:59) [MSC v.1916 64 bit (AMD64)]
